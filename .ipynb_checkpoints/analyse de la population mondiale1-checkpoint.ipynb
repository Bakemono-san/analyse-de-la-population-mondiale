# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from functools import reduce
from tools import calPopRegions, continentTaux, continentTauxAll

# %%
data = pd.read_csv('PopulationByAgeSex-Copy1.csv',index_col='Time',parse_dates=True)

# %%
data
# Out:
#                Id  LocID     Location  PopMale_0_4  PopFemale_0_4  \
# Time
# 1950-01-01      1      4  Afghanistan      630.044        661.578
# 1951-01-01      2      4  Afghanistan      641.199        673.293
# 1952-01-01      3      4  Afghanistan      650.825        669.274
# 1953-01-01      4      4  Afghanistan      659.896        663.606
# 1954-01-01      5      4  Afghanistan      670.694        663.295
# ...           ...    ...          ...          ...            ...
# 2096-01-01  66889    716     Zimbabwe      953.505        939.918
# 2097-01-01  66890    716     Zimbabwe      950.059        936.463
# 2098-01-01  66891    716     Zimbabwe      946.047        932.455
# 2099-01-01  66892    716     Zimbabwe      941.631        928.001
# 2100-01-01  66893    716     Zimbabwe      937.118        923.351
#
#             PopTotal_0_4  PopMale_5_9  PopFemale_5_9  PopTotal_5_9  \
# Time
# 1950-01-01      1291.622      516.206        487.335      1003.541
# ...

# %%
data[['PopMale','PopFemale','PopTotal']].describe()
# Out:
#             PopMale     PopFemale      PopTotal
# count  6.689300e+04  6.689300e+04  6.689300e+04
# mean   3.395770e+05  3.354644e+05  6.750414e+05
# std    7.439528e+05  7.319416e+05  1.475830e+06
# min    6.812000e+00  6.889000e+00  1.376300e+01
# 25%    3.286896e+03  3.269616e+03  6.585116e+03
# 50%    3.443957e+04  3.460833e+04  6.963185e+04
# 75%    3.174896e+05  3.221890e+05  6.403540e+05
# max    5.445805e+06  5.429588e+06  1.087539e+07

# %%
DataLocation = data['Location'].unique()

# %%
contries = dict()
popMale = dict()
popFemale = dict()
for i in DataLocation:
    contries.update({i : data[data['Location']== i]['PopTotal'].sum(axis=0)})
    popMale.update({i : data[data['Location'] == i]['PopMale'].sum(axis=0)})
    popFemale.update({i : data[data['Location'] == i]['PopFemale'].sum(axis=0)})

# %%
afrique = contries['Africa']
afriqueCentrale = contries['African Union: Central Africa']
afriqueDeLEst = contries['African Union: Eastern Africa']
afriqueDeLOuest = contries['African Union: Western Africa']
afriqueDuNord = contries['African Union: Northern Africa']
afriqueDuSud = contries['African Union: Southern Africa']
name = data[data['LocID']==903]['Location'].unique()

# %%
print(afriqueCentrale)
# Out:
# 36332725.02300001

# %%
def pourcentage_pop(arg):
    return (arg/afrique)*100

# %%
pourcentageAfriqueCentrale = pourcentage_pop(afriqueCentrale)
pourcentageAfriqueDeLEst = pourcentage_pop(afriqueDeLEst)
pourcentageAfriqueDeLOuest = pourcentage_pop(afriqueDeLOuest)
pourcentageAfriqueDuNord = pourcentage_pop(afriqueDuNord)
pourcentageAfriqueDuSud = pourcentage_pop(afriqueDuSud)
sizes = [pourcentageAfriqueCentrale,pourcentageAfriqueDeLEst,pourcentageAfriqueDeLOuest,pourcentageAfriqueDuNord,pourcentageAfriqueDuSud]
labels = ['population du Centre','population Est','population Ouest','population Du Nord','population Du Sud']
explode = (0, 0.1,0, 0, 0)

# %%
fig1, ax1 = plt.subplots(figsize=(20,10))
ax1.pie(sizes,explode=explode,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('repartition de la population africaine')
plt.legend()
plt.show()

# %%
calPopRegions(afriqueDeLOuest, afriqueDeLEst, afriqueDuSud, afriqueDuNord, afriqueCentrale, afrique, name )

# %%
def pourcentage_popMale(arg):
    return (arg/afrique)*100

# %%
popMaleafrique = popMale['Africa']
popFemaleafrique = popFemale['Africa']

# %%
pourcenatge_male_afrique = pourcentage_popMale(popMaleafrique)
pourcenatge_female_afrique = pourcentage_popMale(popFemaleafrique)

# %%
sizes = [pourcenatge_male_afrique,pourcenatge_female_afrique]
labels = ['pourcenatge_male_afrique','pourcenatge_female_afrique']
explode = (0,0.1)

# %%
fig1,ax1 = plt.subplots()
ax1.pie(sizes,explode=explode,labels=labels, autopct='%2.2f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
