# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDRegressor

# %%
data = pd.read_csv("PopulationByAgeSex-Copy1.csv", index_col="Time", parse_dates=True)

# %%
data
# Out:
#                Id  LocID     Location  PopMale_0_4  PopFemale_0_4  \
# Time
# 1950-01-01      1      4  Afghanistan      630.044        661.578
# 1951-01-01      2      4  Afghanistan      641.199        673.293
# 1952-01-01      3      4  Afghanistan      650.825        669.274
# 1953-01-01      4      4  Afghanistan      659.896        663.606
# 1954-01-01      5      4  Afghanistan      670.694        663.295
# ...           ...    ...          ...          ...            ...
# 2096-01-01  66889    716     Zimbabwe      953.505        939.918
# 2097-01-01  66890    716     Zimbabwe      950.059        936.463
# 2098-01-01  66891    716     Zimbabwe      946.047        932.455
# 2099-01-01  66892    716     Zimbabwe      941.631        928.001
# 2100-01-01  66893    716     Zimbabwe      937.118        923.351
#
#             PopTotal_0_4  PopMale_5_9  PopFemale_5_9  PopTotal_5_9  \
# Time
# 1950-01-01      1291.622      516.206        487.335      1003.541
# 1951-01-01      1314.492      525.302        502.402      1027.704
# 1952-01-01      1320.099      533.097        521.672      1054.769
# 1953-01-01      1323.502      538.351        541.216      1079.567
# 1954-01-01      1333.989      540.820        557.196      1098.016
# ...                  ...          ...            ...           ...
# 2096-01-01      1893.423      968.045        956.123      1924.168
# 2097-01-01      1886.522      963.764        951.798      1915.562
# 2098-01-01      1878.502      959.864        947.789      1907.653
# 2099-01-01      1869.632      956.124        943.898      1900.022
# 2100-01-01      1860.469      952.224        939.830      1892.054
#
#             PopMale_10_14  ...  PopMale_95_99  PopFemale_95_99  \
# Time                       ...
# 1950-01-01        461.378  ...          0.004            0.003
# 1951-01-01        465.611  ...          0.007            0.005
# 1952-01-01        471.928  ...          0.012            0.009
# 1953-01-01        480.448  ...          0.015            0.013
# 1954-01-01        489.780  ...          0.014            0.011
# ...                   ...  ...            ...              ...
# 2096-01-01        992.221  ...          3.108           11.248
# 2097-01-01        986.112  ...          4.189           13.881
# 2098-01-01        980.369  ...          5.003           15.945
# 2099-01-01        975.007  ...          4.960           16.180
# 2100-01-01        970.074  ...          3.581           13.659
#
#             PopTotal_95_99  PopMale_100Plus  PopFemale_100Plus  \
# Time
# 1950-01-01           0.007            0.000              0.000
# 1951-01-01           0.012            0.000              0.000
# 1952-01-01           0.021            0.000              0.000
# 1953-01-01           0.028            0.000              0.000
# 1954-01-01           0.025            0.000              0.000
# ...                    ...              ...                ...
# 2096-01-01          14.356            0.142              0.883
# 2097-01-01          18.070            0.154              0.947
# 2098-01-01          20.948            0.169              1.022
# 2099-01-01          21.140            0.185              1.107
# 2100-01-01          17.240            0.204              1.203
#
#             PopTotal_100Plus    PopMale  PopFemale   PopTotal  \
# Time
# 1950-01-01             0.000   4099.243   3652.874   7752.117
# 1951-01-01             0.000   4134.756   3705.395   7840.151
# 1952-01-01             0.000   4174.450   3761.546   7935.996
# 1953-01-01             0.000   4218.336   3821.348   8039.684
# 1954-01-01             0.000   4266.484   3884.832   8151.316
# ...                      ...        ...        ...        ...
# 2096-01-01             1.025  15008.463  15932.316  30940.779
# 2097-01-01             1.101  15008.822  15943.386  30952.208
# 2098-01-01             1.191  15007.570  15952.241  30959.811
# 2099-01-01             1.292  15004.963  15959.089  30964.052
# 2100-01-01             1.407  15001.252  15964.169  30965.421
#
#             YearDataCompleted
# Time
# 1950-01-01                  1
# 1951-01-01                  1
# 1952-01-01                  1
# 1953-01-01                  1
# 1954-01-01                  1
# ...                       ...
# 2096-01-01                  1
# 2097-01-01                  1
# 2098-01-01                  1
# 2099-01-01                  1
# 2100-01-01                  1
#
# [66893 rows x 70 columns]

# %% [markdown]
# ## creons nos Targets et nos Features

# %%
## Targets
y = data['PopTotal']
y = y.values.reshape(-1,1)

## Features
x = data.drop(['PopTotal', 'Location'], axis =1)

# %%
y
# Out:
# array([[ 7752.117],
#        [ 7840.151],
#        [ 7935.996],
#        ...,
#        [30959.811],
#        [30964.052],
#        [30965.421]])

# %% [markdown]
# ## passons a L'encodage

# %%
## encodage 
encoder = OrdinalEncoder()

x_encodé = encoder.fit_transform(x)
y_encodé = encoder.fit_transform(y)

# %%
## creons nos variables test et train

x_train, x_test, y_train, y_test = train_test_split(x_encodé, y_encodé)

print(f'train :{x_train.shape},{y_train.shape}')
print(f'test :{x_test.shape},{y_test.shape}')
# Out:
# train :(50169, 68),(50169, 1)
# test :(16724, 68),(16724, 1)

# %% [markdown]
# ## faisons la normalisation et la modelisation

# %%
model = make_pipeline(StandardScaler(), SGDRegressor())
model.fit(x_train, y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1225: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %%
## evaluons le model

model.score(x_test, y_test)
# Out:
# 0.9999929703589605

# %%
prediction = model.predict(x_encodé[0:50])
target = y_encodé[0:50]

# %%
## visualisation des performances du model
plt.plot(prediction, label="prediction")
plt.plot(target, label="Targets")
plt.legend()
plt.show()
